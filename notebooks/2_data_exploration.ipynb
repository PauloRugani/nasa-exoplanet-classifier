# %% [markdown]
# # Data exploration

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
pd.set_option('display.max_columns', None)

# %%
raw_df = pd.read_csv('../data/processed/1.1_merged_data.csv', sep=';')
raw_df
# Out:
#                STATUS  ORBITAL_PERIOD_DAYS  TRANSIT_DURATION_HOURS  \
# 0           CONFIRMED             9.488036                2.957500
# 1           CONFIRMED            54.418383                4.507000
# 2           CANDIDATE            19.899140                1.782200
# 3      FALSE POSITIVE             1.736952                2.406410
# 4           CONFIRMED             2.525592                1.654500
# ...               ...                  ...                     ...
# 17262              FP             3.443800                2.572000
# 17263              FP            14.537800                6.826000
# 17264              FP             8.413486                3.556833
# 17265              FP             0.941436                1.360700
# 17266              FP             1.507896                2.759000
#
#        TRANSIT_DEPTH_PPM  PLANET_RADIUS_REARTH  PLANET_INSOLATION_EFLUX  \
# 0             615.800000              2.260000                93.590000
# ...

# %%
raw_df.shape
# Out:
# (17267, 10)

# %%
raw_df.columns
# Out:
# Index(['STATUS', 'ORBITAL_PERIOD_DAYS', 'TRANSIT_DURATION_HOURS',
#        'TRANSIT_DEPTH_PPM', 'PLANET_RADIUS_REARTH', 'PLANET_INSOLATION_EFLUX',
#        'PLANET_EQ_TEMP_K', 'STELLAR_TEFF_K', 'STELLAR_LOGG_CMS2',
#        'STELLAR_RADIUS_RSUN'],
#       dtype='object')

# %%
raw_df.duplicated().sum()
# Out:
# np.int64(0)

# %%
pd.DataFrame(raw_df.dtypes)
# Out:
#                                0
# STATUS                    object
# ORBITAL_PERIOD_DAYS      float64
# TRANSIT_DURATION_HOURS   float64
# TRANSIT_DEPTH_PPM        float64
# PLANET_RADIUS_REARTH     float64
# PLANET_INSOLATION_EFLUX  float64
# PLANET_EQ_TEMP_K         float64
# STELLAR_TEFF_K           float64
# STELLAR_LOGG_CMS2        float64
# STELLAR_RADIUS_RSUN      float64

# %%
raw_df.isna().sum()
# Out:
# STATUS                        0
# ORBITAL_PERIOD_DAYS         107
# TRANSIT_DURATION_HOURS        0
# TRANSIT_DEPTH_PPM           363
# PLANET_RADIUS_REARTH        869
# PLANET_INSOLATION_EFLUX     497
# PLANET_EQ_TEMP_K            674
# STELLAR_TEFF_K              524
# STELLAR_LOGG_CMS2          1219
# STELLAR_RADIUS_RSUN         870
# dtype: int64

# %%
raw_df.describe()
# Out:
#        ORBITAL_PERIOD_DAYS  TRANSIT_DURATION_HOURS  TRANSIT_DEPTH_PPM  \
# count         17160.000000            17267.000000       1.690400e+04
# mean             50.027673                4.478497       1.671233e+04
# std             998.969196                5.136641       6.229679e+04
# min               0.152076                0.052000       0.000000e+00
# 25%               2.573540                2.122698       3.210000e+02
# 50%               5.652540                3.214000       1.238500e+03
# 75%              17.637781                4.892500       7.630000e+03
# max          129995.778400              138.540000       1.541400e+06
#
#        PLANET_RADIUS_REARTH  PLANET_INSOLATION_EFLUX  PLANET_EQ_TEMP_K  \
# count          16398.000000             1.677000e+04      16593.000000
# mean              62.265485             5.277332e+03       1173.282929
# std             2305.774959             1.184486e+05        791.399741
# ...

# %%
sns.boxplot(raw_df[raw_df.columns[:4]])
plt.show()
sns.boxplot(raw_df[raw_df.columns[4:7]])
plt.show()
sns.boxplot(raw_df[raw_df.columns[7:10]])
plt.show()
